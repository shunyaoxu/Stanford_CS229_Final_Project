# %% [markdown]
# # CNN Implementation CNN to Solve 3x3 Jigsaw

# %% [markdown]
# ### 1. Setup

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl
import pandas as pd
import numpy as np
import tensorflow as tf
import time
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import MaxPooling1D, Conv1D, GlobalAveragePooling1D, Reshape
from tensorflow.keras.layers import TimeDistributed, GlobalAveragePooling2D, ZeroPadding2D, MaxPooling2D, Flatten, Dense, Input, Dropout, Conv2D, BatchNormalization, MaxPool2D, Activation
from tensorflow.keras.layers import TimeDistributed as td
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 2. Prepare the Data

# %%
train_path = "E:/Stanford_Spring_2122/CS229/Final_Project/data/puzzle_3x3/train/"
val_path = "E:/Stanford_Spring_2122/CS229/Final_Project/data/puzzle_3x3/valid/"
test_path = "E:/Stanford_Spring_2122/CS229/Final_Project/data/puzzle_3x3/test/"

# %% [markdown]
# Load Training Dataset

# %%
# Load Training Dataset
data_train = []
label_train = []
label_train_onehot = []

df_train = pd.read_csv(r"E:/Stanford_Spring_2122/CS229/Final_Project/data/puzzle_3x3/train.csv", header = 0)
for i in range(90000):# df_train.shape[0]
    img_name = df_train['image'][i]
    img = plt.imread(train_path + img_name)
    #print(img.shape)
    img_split = []
    img_split.append(img[:67,:67,:].reshape(1,67,67,3))
    img_split.append(img[:67,67:134,:].reshape(1,67,67,3))
    img_split.append(img[:67,134:,:].reshape(1,67,67,3))
    img_split.append(img[67:134,:67,:].reshape(1,67,67,3))
    img_split.append(img[67:134,67:134,:].reshape(1,67,67,3))
    img_split.append(img[67:134,134:,:].reshape(1,67,67,3))
    img_split.append(img[134:,:67,:].reshape(1,67,67,3))
    img_split.append(img[134:,67:134,:].reshape(1,67,67,3))
    img_split.append(img[134:,134:,:].reshape(1,67,67,3))
    img_split = np.concatenate(img_split, axis=0)
    data_train.append(img_split.reshape(1,9,67,67,3))
    
    label = df_train['label'][i].split()
    label = [int(i) for i in label]
    label_train.append(np.array(label).reshape(1,9))
    
data_train = np.concatenate(data_train, axis=0)
label_train = np.concatenate(label_train, axis=0)


print("training data: ", data_train.shape)
print("training label: ", label_train.shape)
# Out:
# training data:  (90000, 9, 67, 67, 3)
# training label:  (90000, 9)

# %% [markdown]
# Load Validation Dataset

# %%
# Load Validation Set
data_val = []
label_val = []

for i in range(90000, 93000):# size of validation set
    img_name = df_train['image'][i]
    img = plt.imread(train_path + img_name)
    img_split = []
    img_split.append(img[:67,:67,:].reshape(1,67,67,3))
    img_split.append(img[:67,67:134,:].reshape(1,67,67,3))
    img_split.append(img[:67,134:,:].reshape(1,67,67,3))
    img_split.append(img[67:134,:67,:].reshape(1,67,67,3))
    img_split.append(img[67:134,67:134,:].reshape(1,67,67,3))
    img_split.append(img[67:134,134:,:].reshape(1,67,67,3))
    img_split.append(img[134:,:67,:].reshape(1,67,67,3))
    img_split.append(img[134:,67:134,:].reshape(1,67,67,3))
    img_split.append(img[134:,134:,:].reshape(1,67,67,3))
    img_split = np.concatenate(img_split, axis=0)
    data_val.append(img_split.reshape(1,9,67,67,3))
    
    label = df_train['label'][i].split()
    label = [int(i) for i in label]
    label_val.append(np.array(label).reshape(1,9))

data_val = np.concatenate(data_val, axis=0)
label_val = np.concatenate(label_val, axis=0)

print("validation data: ", data_val.shape)
print("validation label: ", label_val.shape)
# Out:
# validation data:  (3000, 9, 67, 67, 3)
# validation label:  (3000, 9)

# %% [markdown]
# Load Testing Set

# %%
data_test = []
label_test = []

df_test = pd.read_csv(r"E:/Stanford_Spring_2122/CS229/Final_Project/data/puzzle_3x3/test.csv", header = 0)
for i in range(df_test.shape[0]):
    img_name = df_test['image'][i]
    img = plt.imread(test_path + img_name)
    img_split = []
    img_split.append(img[:67,:67,:].reshape(1,67,67,3))
    img_split.append(img[:67,67:134,:].reshape(1,67,67,3))
    img_split.append(img[:67,134:,:].reshape(1,67,67,3))
    img_split.append(img[67:134,:67,:].reshape(1,67,67,3))
    img_split.append(img[67:134,67:134,:].reshape(1,67,67,3))
    img_split.append(img[67:134,134:,:].reshape(1,67,67,3))
    img_split.append(img[134:,:67,:].reshape(1,67,67,3))
    img_split.append(img[134:,67:134,:].reshape(1,67,67,3))
    img_split.append(img[134:,134:,:].reshape(1,67,67,3))
    img_split = np.concatenate(img_split, axis=0)
    data_test.append(img_split.reshape(1,9,67,67,3))
    
    label = df_test['label'][i].split()
    label = [int(i) for i in label]
    label_test.append(np.array(label).reshape(1,9))

data_test = np.concatenate(data_test, axis=0)
label_test = np.concatenate(label_test, axis=0)

print("testing data: ", data_test.shape)
print("testing label: ", label_test.shape)
# Out:
# testing data:  (2181, 9, 67, 67, 3)
# testing label:  (2181, 9)

# %% [markdown]
# Show some example training images and their labels.

# %%
plt.figure(figsize=(12, 8))
for i in range(6):
    plt.subplot(2, 3, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title("Label: " + df_train['label'][i])
    plt.subplots_adjust(wspace=None, hspace=None)
    
    img_name = df_train['image'][i]
    img = plt.imread(train_path + img_name)
    plt.imshow(img)
plt.show()

# %% [markdown]
# ### 3. Set Hyperparameters for CNN Model

# %%
lr = 0.01 # learning rate
decay = 1e-4 # learning rate decay
epochs = 20
batch_size = 128

input_shape = (9, 67, 67, 3)
dropout_rate = 0.3

# %% [markdown]
# ### 4. Build the CNN Model

# %%
# Initiate a Keras sequential model
model = keras.models.Sequential()

# Feature Extractor
model.add(td(ZeroPadding2D(2), input_shape=input_shape))
model.add(td(Conv2D(32, kernel_size=(5,5), padding='same', activation='relu', strides=2)))
model.add(td(BatchNormalization()))
model.add(td(Dropout(dropout_rate)))

model.add(td(Conv2D(32, kernel_size=(5,5), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(MaxPooling2D()))

model.add(td(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(Dropout(dropout_rate)))

model.add(td(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(MaxPooling2D()))

model.add(td(Conv2D(128, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(Dropout(dropout_rate)))

model.add(td(Conv2D(128, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(MaxPooling2D()))

model.add(td(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(Dropout(dropout_rate)))

model.add(td(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
model.add(td(BatchNormalization()))
model.add(td(MaxPooling2D()))

# Flatten Layer
model.add(Flatten())

# Fully Connected Layers
model.add(Dense(600, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(400, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))
model.add(Dense(81))
model.add(Reshape((9, 9)))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_35 (TimeDis (None, 9, 71, 71, 3)      0
# _________________________________________________________________
# time_distributed_36 (TimeDis (None, 9, 36, 36, 32)     2432
# _________________________________________________________________
# time_distributed_37 (TimeDis (None, 9, 36, 36, 32)     128
# _________________________________________________________________
# time_distributed_38 (TimeDis (None, 9, 36, 36, 32)     0
# _________________________________________________________________
# time_distributed_39 (TimeDis (None, 9, 36, 36, 32)     25632
# _________________________________________________________________
# time_distributed_40 (TimeDis (None, 9, 36, 36, 32)     128
# _________________________________________________________________
# time_distributed_41 (TimeDis (None, 9, 18, 18, 32)     0
# _________________________________________________________________
# time_distributed_42 (TimeDis (None, 9, 18, 18, 64)     18496
# _________________________________________________________________
# time_distributed_43 (TimeDis (None, 9, 18, 18, 64)     256
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 9, 18, 18, 64)     0
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 9, 18, 18, 64)     36928
# _________________________________________________________________
# time_distributed_46 (TimeDis (None, 9, 18, 18, 64)     256
# _________________________________________________________________
# time_distributed_47 (TimeDis (None, 9, 9, 9, 64)       0
# _________________________________________________________________
# time_distributed_48 (TimeDis (None, 9, 9, 9, 128)      73856
# _________________________________________________________________
# time_distributed_49 (TimeDis (None, 9, 9, 9, 128)      512
# _________________________________________________________________
# time_distributed_50 (TimeDis (None, 9, 9, 9, 128)      0
# _________________________________________________________________
# time_distributed_51 (TimeDis (None, 9, 9, 9, 128)      147584
# _________________________________________________________________
# time_distributed_52 (TimeDis (None, 9, 9, 9, 128)      512
# _________________________________________________________________
# time_distributed_53 (TimeDis (None, 9, 4, 4, 128)      0
# _________________________________________________________________
# time_distributed_54 (TimeDis (None, 9, 4, 4, 256)      295168
# _________________________________________________________________
# time_distributed_55 (TimeDis (None, 9, 4, 4, 256)      1024
# _________________________________________________________________
# time_distributed_56 (TimeDis (None, 9, 4, 4, 256)      0
# _________________________________________________________________
# time_distributed_57 (TimeDis (None, 9, 4, 4, 256)      590080
# _________________________________________________________________
# time_distributed_58 (TimeDis (None, 9, 4, 4, 256)      1024
# _________________________________________________________________
# time_distributed_59 (TimeDis (None, 9, 2, 2, 256)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 600)               5530200
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 600)               2400
# _________________________________________________________________
# dense_7 (Dense)              (None, 400)               240400
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 400)               1600
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 81)                32481
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 9, 9)              0
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9)              0
# =================================================================
# Total params: 7,001,097
# Trainable params: 6,997,177
# Non-trainable params: 3,920
# _________________________________________________________________
# None

# %% [markdown]
# ### 5. Training the CNN Model

# %%
adam = tf.keras.optimizers.Adam(learning_rate=lr, decay=decay)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
history = model.fit(data_train,
                    label_train, 
                    epochs=epochs, batch_size=batch_size, 
                    verbose=1, 
                    validation_data=(data_val, label_val))
# Out:
# Epoch 1/20
# 704/704 [==============================] - 2562s 4s/step - loss: 2.2134 - accuracy: 0.1446 - val_loss: 2.0355 - val_accuracy: 0.2035
# Epoch 2/20
# 704/704 [==============================] - 2742s 4s/step - loss: 1.9342 - accuracy: 0.2240 - val_loss: 1.9209 - val_accuracy: 0.2285
# Epoch 3/20
# 704/704 [==============================] - 2705s 4s/step - loss: 1.8305 - accuracy: 0.2581 - val_loss: 1.8245 - val_accuracy: 0.2872
# Epoch 4/20
# 704/704 [==============================] - 2772s 4s/step - loss: 1.7128 - accuracy: 0.3189 - val_loss: 1.7556 - val_accuracy: 0.3381
# Epoch 5/20
# 704/704 [==============================] - 2758s 4s/step - loss: 1.6247 - accuracy: 0.3540 - val_loss: 1.6027 - val_accuracy: 0.3674
# Epoch 6/20
# 704/704 [==============================] - 2569s 4s/step - loss: 1.5537 - accuracy: 0.3832 - val_loss: 1.5924 - val_accuracy: 0.3756
# Epoch 7/20
# 704/704 [==============================] - 2590s 4s/step - loss: 1.4957 - accuracy: 0.4056 - val_loss: 1.5487 - val_accuracy: 0.3913
# Epoch 8/20
# 704/704 [==============================] - 2587s 4s/step - loss: 1.4456 - accuracy: 0.4265 - val_loss: 1.4599 - val_accuracy: 0.4230
# Epoch 9/20
# 704/704 [==============================] - 2567s 4s/step - loss: 1.3919 - accuracy: 0.4481 - val_loss: 1.4784 - val_accuracy: 0.4202
# Epoch 10/20
# 704/704 [==============================] - 2588s 4s/step - loss: 1.3409 - accuracy: 0.4691 - val_loss: 1.3882 - val_accuracy: 0.4510
# Epoch 11/20
# 704/704 [==============================] - 2591s 4s/step - loss: 1.2918 - accuracy: 0.4895 - val_loss: 1.3841 - val_accuracy: 0.4576
# Epoch 12/20
# 704/704 [==============================] - 2597s 4s/step - loss: 1.2399 - accuracy: 0.5103 - val_loss: 1.3903 - val_accuracy: 0.4571
# Epoch 13/20
# 704/704 [==============================] - 2592s 4s/step - loss: 1.1848 - accuracy: 0.5340 - val_loss: 1.3765 - val_accuracy: 0.4662
# Epoch 14/20
# 704/704 [==============================] - 2595s 4s/step - loss: 1.1302 - accuracy: 0.5563 - val_loss: 1.4197 - val_accuracy: 0.4598
# Epoch 15/20
# 704/704 [==============================] - 2614s 4s/step - loss: 1.0748 - accuracy: 0.5788 - val_loss: 1.4138 - val_accuracy: 0.4678
# Epoch 16/20
# 704/704 [==============================] - 2585s 4s/step - loss: 1.0174 - accuracy: 0.6025 - val_loss: 1.4648 - val_accuracy: 0.4607
# Epoch 17/20
# 704/704 [==============================] - 2581s 4s/step - loss: 0.9643 - accuracy: 0.6250 - val_loss: 1.5354 - val_accuracy: 0.4422
# Epoch 18/20
# 704/704 [==============================] - 2614s 4s/step - loss: 0.9106 - accuracy: 0.6464 - val_loss: 1.5546 - val_accuracy: 0.4527
# Epoch 19/20
# 704/704 [==============================] - 2746s 4s/step - loss: 0.8615 - accuracy: 0.6664 - val_loss: 1.5966 - val_accuracy: 0.4533
# Epoch 20/20
# 704/704 [==============================] - 2728s 4s/step - loss: 0.8142 - accuracy: 0.6859 - val_loss: 1.6429 - val_accuracy: 0.4517

# %% [markdown]
# Save trained model as .h5

# %%
model.save("CNN_3x3_20epoch_split_0.01.h5")

# %% [markdown]
# Plot training result

# %%
# Rebuild the matplotlib font cache
#fm._rebuild()
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'DejaVu Sans' # font
plt.rcParams['font.size'] = 18         # font size
plt.rcParams['axes.linewidth'] = 2     # axes width

fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0, 0, 1, 1])    # Add axes object to our figure that takes up entire figure
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ax.plot(history.history["accuracy"], linewidth=2, color='b', label="Train Acc", alpha = 1)
ax.plot(history.history["val_accuracy"], linewidth=2, color='r', label="Val Acc", alpha = 1)
ax.set_ylabel('Accuracy', labelpad=10, fontsize=20)
ax.set_xlabel('Epochs', labelpad=10, fontsize=20)
ax.grid(color='g', ls = '-.', lw = 0.5)
plt.legend(loc="lower right", fontsize=20)
plt.title("2D CNN Model for 3x3 Puzzle")
plt.savefig('3x3Acc_20epoch_split_0.01.png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %%
# Rebuild the matplotlib font cache
#fm._rebuild()
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'DejaVu Sans' # font
plt.rcParams['font.size'] = 18         # font size
plt.rcParams['axes.linewidth'] = 2     # axes width

fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0, 0, 1, 1])    # Add axes object to our figure that takes up entire figure
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ax.plot(history.history["loss"], linewidth=2, color='b', label="Train Loss", alpha = 1)
ax.plot(history.history["val_loss"], linewidth=2, color='r', label="Val Loss", alpha = 1)
ax.set_ylabel('Loss', labelpad=10, fontsize=20)
ax.set_xlabel('Epochs', labelpad=10, fontsize=20)
ax.grid(color='g', ls = '-.', lw = 0.5)
plt.legend(loc="upper right", fontsize=20)
plt.title("2D CNN Model for 3x3 Puzzle")
plt.savefig('3x3Loss_20epoch_split_0.01.png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 6. Evaluation

# %%
model_loaded = keras.models.load_model("CNN_3x3_20epoch_split_0.01.h5")
outputs = model_loaded.predict(data_test)
predictions = np.argmax(outputs, axis=2)

compare = (predictions == label_test)
num_correct = np.sum(compare)
print(f"Accuracy on Test Set = {round(num_correct / (predictions.shape[0] * predictions.shape[1]) * 100, 2)}%")
# Out:
# Accuracy on Test Set = 44.05%

# %% [markdown]
# Example prediction

# %%
from util import *

plt.figure(figsize=(15, 20))
for i in range(6):
    plt.subplot(6, 3, 3*i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title("Shuffled Img", fontsize=16)
    plt.subplots_adjust(wspace=None, hspace=None)
    randInt = np.random.randint(2181)
    img_name = df_test['image'][randInt]
    img = plt.imread(test_path + img_name)
    plt.imshow(img)
    
    plt.subplot(6, 3, 3*i+2)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title("Ground Truth: " + df_test['label'][randInt], fontsize=16)
    plt.subplots_adjust(wspace=None, hspace=None)
    plt.imshow(rearrange3x3(label_test[randInt], data_test[randInt]).astype(int))
    
    plt.subplot(6, 3, 3*i+3)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    predicted_label = ""
    for a in predictions[randInt]:
        predicted_label += " " + str(a)
    plt.title("Prediction:" + predicted_label, fontsize=16)
    plt.subplots_adjust(wspace=None, hspace=None)
    plt.imshow(rearrange3x3(predictions[randInt], data_test[randInt]).astype(int))
plt.show()
